# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc

# %%
seoul = pd.read_excel('../data/2019_standardized.xlsx')
seoul.head()
# Out:
#    자치구     ATM 수     가로등 수    경찰관서 수      공원 수     면적(㎢)  반려동물 가구 비율(%, 인구 수)  \
# 0  강남구  3.554607  2.337440  1.295863  1.144578  1.676100             1.761167
# 1  강동구 -0.349297 -0.088025 -0.176709  0.264570  0.041699             0.124775
# 2  강북구 -0.854407 -1.294033 -0.667566 -0.927699 -0.066823            -0.642284
# 3  강서구  1.422870  0.466169 -1.158423  1.570389  1.888759            -0.130911
# 4  관악구  0.344160 -0.923160  0.559577 -0.132853  0.587595            -1.511617
#
#     버스정류장 수    범죄발생건수    소방관서 수   인구 수(명)      카페 수     편의점 수   행복지수 종합
# 0  0.972781  2.725242  1.081180  1.194857  3.136826  3.582847  0.770796
# 1 -0.545995 -0.114559  0.236508  0.318725 -0.341270 -0.075670 -1.672995
# 2  0.036680 -0.266475 -0.608164 -0.660131 -0.876584 -0.892378  1.171417
# 3  1.498144  0.670918  1.081180  1.578310  0.162215  1.207727 -0.391007
# 4  0.332794  1.019635 -0.608164  0.932581 -0.263143  0.474357  1.291604

# %%
seoul.columns
# Out:
# Index(['기간', '자치구', '인구 수(명)', '면적', '범죄발생건수', '경찰관서 수', '소방관서 수', '카페 수',
#        '편의점 수', '공원 수', '버스정류장 수', '가로등 수', 'ATM 수', '반려동물 가구 비율(%, 인구 수)',
#        '행복지수 종합'],
#       dtype='object')

# %%
seoul.sort_values(by = '인구 수(명)', ascending = False).head(5)
# Out:
#       기간  자치구  인구 수(명)     면적  범죄발생건수  경찰관서 수  소방관서 수  카페 수  편의점 수  공원 수  \
# 17  2019  송파구   682741  33.87    5698      21       7  1914    550   169
# 3   2019  강서구   598273  41.44    4924      13       7  1399    518   170
# 0   2019  강남구   550209  39.50    7304      23       7  3455    803   155
# 8   2019  노원구   537303  35.44    4153      18       6   971    342   181
# 4   2019  관악구   517334  29.57    5328      20       5  1105    430   110
#
#     버스정류장 수  가로등 수  ATM 수  반려동물 가구 비율(%, 인구 수)  행복지수 종합
# 17      430  13520    547                 19.4     6.94
# 3       604   8919    538                 19.8     6.72
# 0       549  13788    787                 23.5     7.01
# 8       546   9510    336                 21.4     7.22
# 4       482   5304    412                 17.1     7.14

# %%
seoul.set_index('자치구', inplace = True)
seoul.head()
# Out:
#         ATM 수     가로등 수    경찰관서 수      공원 수     면적(㎢)  반려동물 가구 비율(%, 인구 수)  \
# 자치구
# 강남구  3.554607  2.337440  1.295863  1.144578  1.676100             1.761167
# 강동구 -0.349297 -0.088025 -0.176709  0.264570  0.041699             0.124775
# 강북구 -0.854407 -1.294033 -0.667566 -0.927699 -0.066823            -0.642284
# 강서구  1.422870  0.466169 -1.158423  1.570389  1.888759            -0.130911
# 관악구  0.344160 -0.923160  0.559577 -0.132853  0.587595            -1.511617
#
#       버스정류장 수    범죄발생건수    소방관서 수   인구 수(명)      카페 수     편의점 수   행복지수 종합
# 자치구
# 강남구  0.972781  2.725242  1.081180  1.194857  3.136826  3.582847  0.770796
# 강동구 -0.545995 -0.114559  0.236508  0.318725 -0.341270 -0.075670 -1.672995
# 강북구  0.036680 -0.266475 -0.608164 -0.660131 -0.876584 -0.892378  1.171417
# 강서구  1.498144  0.670918  1.081180  1.578310  0.162215  1.207727 -0.391007
# 관악구  0.332794  1.019635 -0.608164  0.932581 -0.263143  0.474357  1.291604

# %%
seoul.rename(columns = {seoul.columns[4] : '면적'}, inplace = True)

# %%
seoul.head()
# Out:
#         ATM 수     가로등 수    경찰관서 수      공원 수        면적  반려동물 가구 비율(%, 인구 수)  \
# 자치구
# 강남구  3.554607  2.337440  1.295863  1.144578  1.676100             1.761167
# 강동구 -0.349297 -0.088025 -0.176709  0.264570  0.041699             0.124775
# 강북구 -0.854407 -1.294033 -0.667566 -0.927699 -0.066823            -0.642284
# 강서구  1.422870  0.466169 -1.158423  1.570389  1.888759            -0.130911
# 관악구  0.344160 -0.923160  0.559577 -0.132853  0.587595            -1.511617
#
#       버스정류장 수    범죄발생건수    소방관서 수   인구 수(명)      카페 수     편의점 수   행복지수 종합
# 자치구
# 강남구  0.972781  2.725242  1.081180  1.194857  3.136826  3.582847  0.770796
# 강동구 -0.545995 -0.114559  0.236508  0.318725 -0.341270 -0.075670 -1.672995
# 강북구  0.036680 -0.266475 -0.608164 -0.660131 -0.876584 -0.892378  1.171417
# 강서구  1.498144  0.670918  1.081180  1.578310  0.162215  1.207727 -0.391007
# 관악구  0.332794  1.019635 -0.608164  0.932581 -0.263143  0.474357  1.291604

# %%
print('인구수\n', np.corrcoef(seoul['인구 수(명)'], seoul['범죄발생건수']))
print('면적\n', np.corrcoef(seoul['면적'], seoul['범죄발생건수']))
print('경찰관서 수\n', np.corrcoef(seoul['경찰관서 수'], seoul['범죄발생건수']))
print('소방관서 수\n', np.corrcoef(seoul['소방관서 수'], seoul['범죄발생건수']))
print('카페 수\n', np.corrcoef(seoul['카페 수'], seoul['범죄발생건수']))
print('편의점 수\n', np.corrcoef(seoul['편의점 수'], seoul['범죄발생건수']))
print('공원 수\n', np.corrcoef(seoul['공원 수'], seoul['범죄발생건수']))
print('버스정류장 수\n', np.corrcoef(seoul['버스정류장 수'], seoul['범죄발생건수']))
print('가로등 수\n', np.corrcoef(seoul['가로등 수'], seoul['범죄발생건수']))
print('ATM 수\n', np.corrcoef(seoul['ATM 수'], seoul['범죄발생건수']))
print('반려동물 가구 비율(%, 인구 수)\n', np.corrcoef(seoul['반려동물 가구 비율(%, 인구 수)'], seoul['범죄발생건수']))
print('행복지수 종합\n', np.corrcoef(seoul['행복지수 종합'], seoul['범죄발생건수']))
# Out:
# 인구수
#  [[1.         0.50518958]
#  [0.50518958 1.        ]]
# 면적
#  [[1.         0.62978128]
#  [0.62978128 1.        ]]
# 경찰관서 수
#  [[1.         0.34573044]
#  [0.34573044 1.        ]]
# 소방관서 수
#  [[1.         0.54299676]
#  [0.54299676 1.        ]]
# 카페 수
#  [[1.         0.69409927]
#  [0.69409927 1.        ]]
# 편의점 수
#  [[1.        0.8812223]
#  [0.8812223 1.       ]]
# 공원 수
#  [[1.         0.52208546]
#  [0.52208546 1.        ]]
# 버스정류장 수
#  [[1.         0.38733366]
#  [0.38733366 1.        ]]
# 가로등 수
#  [[1.         0.72841828]
#  [0.72841828 1.        ]]
# ATM 수
#  [[1.         0.86892816]
#  [0.86892816 1.        ]]
# 반려동물 가구 비율(%, 인구 수)
#  [[1.         0.39952423]
#  [0.39952423 1.        ]]
# 행복지수 종합
#  [[1.         0.15003105]
#  [0.15003105 1.        ]]

# %%
plt.rc('font', family = 'Malgun Gothic')  # 글씨체 불러오기
plt.rcParams['axes.unicode_minus'] = False # '-' 기호 깨지는거 방지

# %%
plt.figure(figsize = (10, 10))
seoul['범죄발생건수'].plot(kind = 'barh', grid = True)
plt.show()

# %%
plt.figure(figsize = (10, 10))
seoul['범죄발생건수'].sort_values().plot(kind = 'barh', grid = True)
plt.show()

# %%
plt.figure(figsize = (10, 10))
plt.scatter(seoul['인구 수(명)'], seoul['범죄발생건수'], s = 50)
plt.title('인구수 대비 범죄발생건수')
plt.xlabel('인구수')
plt.ylabel('범죄발생건수')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(seoul['인구 수(명)'], seoul['범죄발생건수'], 1)
fp1
# Out:
# array([ 5.05189582e-01, -9.99200722e-17])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(-3, 3, 100)

# %%
plt.figure(figsize = (10, 10))
plt.scatter(seoul['인구 수(명)'], seoul['범죄발생건수'], s = 50)
plt.plot(fx, f1(fx), ls = '--', lw = 3, color = 'g')
plt.title('인구수 대비 범죄발생건수')
plt.xlabel('인구수')
plt.ylabel('범죄발생건수')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(seoul['인구 수(명)'], seoul['범죄발생건수'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(-3, 3, 100)

seoul['오차'] = np.abs(seoul['범죄발생건수'] - f1(seoul['인구 수(명)']))

df_sort = seoul.sort_values(by = '오차', ascending =False)
df_sort.head()
# Out:
#          ATM 수     가로등 수    경찰관서 수      공원 수        면적  반려동물 가구 비율(%, 인구 수)  \
# 자치구
# 강남구   3.554607  2.337440  1.295863  1.144578  1.676100             1.761167
# 도봉구  -1.231099 -1.210634 -1.894708 -1.012861 -0.390196            -0.437735
# 영등포구  0.755097  0.604141 -0.422137 -0.189628  0.037314             2.477089
# 성북구  -0.272246 -0.815550  2.032148  0.520056  0.040602             0.994108
# 중구    0.352721  0.368551  0.559577 -1.183185 -1.562010            -1.358206
#
#        버스정류장 수    범죄발생건수    소방관서 수   인구 수(명)      카페 수     편의점 수   행복지수 종합  \
# 자치구
# 강남구   0.972781  2.725242  1.081180  1.194857  3.136826  3.582847  0.770796
# 도봉구  -0.526891 -1.758018 -0.608164 -0.517038 -1.132667 -1.134057  0.290050
# 영등포구  0.571595  1.444311  0.236508  0.004361  0.292426  0.791040 -0.551255
# 성북구   1.479040 -1.095973 -0.608164  0.433241 -0.332589 -0.325683  0.530423
# 중구   -2.255813  0.155611  1.081180 -2.105794  0.306894 -0.225678 -1.352498
#
#             오차
# 자치구
# 강남구   2.121613
# 도봉구   1.496816
# 영등포구  1.442107
# 성북구   1.314842
# 중구    1.219436

# %%
fp1 = np.polyfit(seoul['편의점 수'], seoul['범죄발생건수'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(-3, 4, 100)

seoul['오차'] = np.abs(seoul['범죄발생건수'] - f1(seoul['편의점 수']))

plt.figure(figsize = (14, 10))
plt.scatter(seoul['편의점 수'], seoul['범죄발생건수'], c = seoul['오차'], s = 50)
plt.plot(fx, f1(fx), ls = '--', lw = 3, color = 'g')

for n in range(10):
    plt.text(df_sort['편의점 수'][n] * 1.02, df_sort['범죄발생건수'][n] * 0.98, df_sort.index[n], fontsize = 15)

plt.xlabel('편의점 수')
plt.ylabel('편의점 수당 범죄발생 비율')

plt.colorbar()
plt.grid()
plt.show()
